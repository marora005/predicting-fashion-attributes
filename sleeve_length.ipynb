# %%
import pandas as pd
import os
df=pd.read_csv("/content/drive/MyDrive/attributes.csv")
df['neck'].fillna(df['neck'].mode()[0], inplace=True)
df['sleeve_length'].fillna(df['sleeve_length'].mode()[0], inplace=True)
df['pattern'].fillna(df['pattern'].mode()[0], inplace=True)
df['neck'] = df['neck'].astype(int)
df['sleeve_length'] = df['sleeve_length'].astype(int)
df['pattern'] = df['pattern'].astype(int)

df.head()
# Out:
#                                             filename  neck  sleeve_length  \
# 0  cdc8cd2a-0938-4970-a3b5-f5ed9595222c1527925869...     6              3
# 1  11469770662809-Metersbonwe-Navy-T-shirt-485146...     5              3
# 2  11479107741104-Tommy-Hilfiger-Men-Navy-Blue-St...     6              1
# 3  f7ad67ab-eeb1-4449-8f63-7b580d2797e71532342804...     6              0
# 4  11516770810185-Splash-Men-Tshirts-767151677081...     6              3
#
#    pattern
# 0        4
# 1        9
# 2        9
# 3        9
# 4        9

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix

# deep learning libraries
import tensorflow as tf
import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import applications
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Flatten, Dense, Dropout
from keras.preprocessing import image

import cv2

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import tqdm
import os

def clean_data(df, folder):
    """
    this functions removes those rows from the DataFrame for which there are
    no images in the dataset
    """
    target = set(os.listdir('/content/drive/MyDrive/' + folder))
    drop_indices = []
    print('[INFO]: Checking if all images are present')
    for index, image_id in df.iterrows():
        if df['filename'][index] not in target:
          drop_indices.append(index)
    print(f"[INFO]: Dropping indices: {drop_indices}")
    df.drop(df.index[drop_indices], inplace=True)
    return df

# %%
labels = clean_data(df.copy(), 'train')
labels = labels.iloc[:1425, :]

sample = clean_data(df, 'val')
sample = sample.iloc[:357, :]
# Out:
# [INFO]: Checking if all images are present
# [INFO]: Dropping indices: [2, 4, 6, 7, 12, 13, 15, 16, 21, 22, 23, 24, 28, 30, 32, 34, 35, 38, 39, 41, 42, 43, 47, 48, 49, 54, 56, 59, 62, 63, 69, 71, 77, 78, 81, 83, 85, 88, 92, 97, 98, 102, 105, 107, 108, 111, 114, 122, 123, 126, 131, 136, 137, 143, 145, 149, 151, 156, 164, 167, 169, 172, 177, 180, 181, 182, 183, 186, 187, 188, 189, 190, 196, 198, 202, 205, 207, 209, 212, 213, 218, 226, 228, 230, 236, 238, 240, 241, 242, 243, 246, 253, 260, 263, 264, 266, 269, 275, 277, 278, 279, 282, 285, 286, 287, 294, 295, 297, 299, 305, 308, 315, 316, 317, 319, 320, 324, 326, 327, 330, 331, 332, 333, 335, 341, 342, 343, 344, 347, 353, 354, 356, 357, 361, 366, 370, 379, 381, 382, 385, 387, 390, 393, 395, 396, 397, 401, 402, 404, 406, 410, 412, 414, 415, 416, 418, 419, 420, 422, 423, 425, 426, 428, 436, 441, 443, 444, 447, 451, 453, 454, 455, 457, 458, 461, 465, 467, 469, 471, 475, 476, 481, 483, 484, 486, 487, 488, 489, 492, 493, 494, 495, 500, 503, 507, 510, 513, 514, 522, 523, 524, 525, 526, 531, 532, 534, 535, 545, 549, 551, 553, 554, 558, 559, 561, 562, 563, 567, 569, 571, 572, 573, 576, 577, 583, 584, 585, 589, 591, 593, 597, 600, 601, 604, 608, 610, 613, 
 833, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 854, 855, 856, 857, 858, 859, 861, 862, 864, 865, 866, 867, 871, 872, 873, 874, 875, 876, 877, 879, 880, 881, 882, 883, 884, 885, 886, 887, 888, 890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 902, 903, 904, 905, 906, 907, 908, 909, 910, 912, 913, 914, 915, 916, 917, 918, 919, 921, 922, 923, 924, 925, 926, 927, 929, 930, 932, 933, 934, 935, 936, 937, 938, 940, 941, 943, 944, 945, 946, 947, 949, 950, 953, 954, 955, 957, 958, 959, 960, 963, 964, 965, 966, 967, 968, 969, 970, 971, 973, 974, 975, 976, 977, ...

# %%
sample.shape, labels.shape,len(os.listdir('/content/drive/MyDrive/val')), len(os.listdir('/content/drive/MyDrive/train'))
# Out:
# ((357, 4), (1425, 4), 357, 1425)

# %%
labels = labels.reset_index()
sample = sample.reset_index()

# %%
labels.head()
# Out:
#    index                                           filename  neck  \
# 0      0  cdc8cd2a-0938-4970-a3b5-f5ed9595222c1527925869...     6
# 1      1  11469770662809-Metersbonwe-Navy-T-shirt-485146...     5
# 2      3  f7ad67ab-eeb1-4449-8f63-7b580d2797e71532342804...     6
# 3      5  11505295751483-FOREVER-21-Men-White-Self-Desig...     1
# 4      8  90044561-8959-460a-a650-49a6772237931537435887...     6
#
#    sleeve_length  pattern
# 0              3        4
# 1              3        9
# 2              0        9
# 3              3        9
# 4              3        9

# %%
sample.head()
# Out:
#    index                                           filename  neck  \
# 0      4  11516770810185-Splash-Men-Tshirts-767151677081...     6
# 1      7  11461827372049-US-Polo-Assn-Navy-T-shirt-20714...     5
# 2     12  94b6ab4b-50c9-4d10-847a-4b4482531d651529052514...     6
# 3     16  11491288646955-FOREVER-21-Men-Tshirts-51914912...     1
# 4     21  11483007751246-HIGHLANDER-Men-Black-Colour-Blo...     6
#
#    sleeve_length  pattern
# 0              3        9
# 1              3        9
# 2              3        8
# 3              3        9
# 4              0        9

# %% [markdown]
# Predicting sleeve length

# %%
label_1 = labels.drop(['index', 'neck', 'pattern'], axis = 1)
sample_1 = sample.drop(['index', 'neck', 'pattern'], axis = 1)
label_1 = label_1.astype({"sleeve_length": str})
sample_1 = sample_1.astype({"sleeve_length": str})

# %%
label_1.head()
# Out:
#                                             filename sleeve_length
# 0  cdc8cd2a-0938-4970-a3b5-f5ed9595222c1527925869...             3
# 1  11469770662809-Metersbonwe-Navy-T-shirt-485146...             3
# 2  f7ad67ab-eeb1-4449-8f63-7b580d2797e71532342804...             0
# 3  11505295751483-FOREVER-21-Men-White-Self-Desig...             3
# 4  90044561-8959-460a-a650-49a6772237931537435887...             3

# %%
# Data agumentation and pre-processing using tensorflow
train_path = '/content/drive/MyDrive/train'
gen = ImageDataGenerator(
        rescale=1./255.,
        horizontal_flip = True,
        validation_split=0.2 # training: 80% data, validation: 20% data
        )

train_generator = gen.flow_from_dataframe(
  label_1, # dataframe
  directory = train_path, # images data path / folder in which images are there
  x_col = 'filename',
  y_col = 'sleeve_length',
  subset="training",
  color_mode="rgb",
  target_size = (331,331), # image height , image width
  class_mode="categorical",
  batch_size=32,
  shuffle=True,
  seed=42,
)


validation_generator = gen.flow_from_dataframe(
  label_1, # dataframe
  directory = train_path, # images data path / folder in which images are there
  x_col = 'filename',
  y_col = 'sleeve_length',
  subset="validation",
  color_mode="rgb",
  target_size = (331,331), # image height , image width
  class_mode="categorical",
  batch_size=32,
  shuffle=True,
  seed=42,
)
# Out:
# Found 1140 validated image filenames belonging to 4 classes.
# Found 285 validated image filenames belonging to 4 classes.

# %%
x,y = next(train_generator)
x.shape # input shape of one record is (331,331,3) , 32: is the batch size
# Out:
# (32, 331, 331, 3)

# %%
a = train_generator.class_indices
class_names = list(a.keys()) # storing class/breed names in a list


def plot_images(img, labels):
  plt.figure(figsize=[15, 10])
  for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(img[i])
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis('off')

plot_images(x,y)

# %%
# load the InceptionResNetV2 architecture with imagenet weights as base
base_model = tf.keras.applications.InceptionResNetV2(
          include_top=False,
          weights='imagenet',
          input_shape=(331,331,3)
          )

base_model.trainable=False
# For freezing the layer we make use of layer.trainable = False
# means that its internal state will not change during training.
# model's trainable weights will not be updated during fit(),
# and also its state updates will not run.

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.BatchNormalization(renorm=True),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
  ])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 1s 0us/step
# 219070464/219055592 [==============================] - 1s 0us/step

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
# categorical cross entropy is taken since its used as a loss function for
# multi-class classification problems where there are two or more output labels.
# using Adam optimizer for better performance
# other optimizers such as sgd can also be used depending upon the model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 9, 9, 1536)       54336736
#  onal)
#
#  batch_normalization_203 (Ba  (None, 9, 9, 1536)       10752
#  tchNormalization)
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               786944
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 55,307,172
# Trainable params: 962,756
# Non-trainable params: 54,344,416
# _________________________________________________________________

# %%
early = tf.keras.callbacks.EarlyStopping( patience=10,
                    min_delta=0.001,
                    restore_best_weights=True)
# early stopping call back

# %%
batch_size=32
STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = validation_generator.n//validation_generator.batch_size

# fit model
history = model.fit(train_generator,
          steps_per_epoch=STEP_SIZE_TRAIN,
          validation_data=validation_generator,
          validation_steps=STEP_SIZE_VALID,
          epochs= 30,
          callbacks=[early]
)
# Out:
# Epoch 1/30
# 35/35 [==============================] - 46s 645ms/step - loss: 0.8098 - accuracy: 0.7888 - val_loss: 0.6179 - val_accuracy: 0.8516
# Epoch 2/30
# 35/35 [==============================] - 17s 484ms/step - loss: 0.6896 - accuracy: 0.8114 - val_loss: 0.5866 - val_accuracy: 0.8438
# Epoch 3/30
# 35/35 [==============================] - 17s 491ms/step - loss: 0.6631 - accuracy: 0.8105 - val_loss: 0.5696 - val_accuracy: 0.8555
# Epoch 4/30
# 35/35 [==============================] - 17s 498ms/step - loss: 0.6055 - accuracy: 0.8258 - val_loss: 0.5048 - val_accuracy: 0.8516
# Epoch 5/30
# 35/35 [==============================] - 17s 497ms/step - loss: 0.5781 - accuracy: 0.8303 - val_loss: 0.5341 - val_accuracy: 0.8477
# Epoch 6/30
# 35/35 [==============================] - 18s 517ms/step - loss: 0.5553 - accuracy: 0.8258 - val_loss: 0.4590 - val_accuracy: 0.8750
# Epoch 7/30
# 35/35 [==============================] - 18s 508ms/step - loss: 0.4792 - accuracy: 0.8394 - val_loss: 0.4923 - val_accuracy: 0.8359
# Epoch 8/30
# 35/35 [==============================] - 18s 501ms/step - loss: 0.4729 - accuracy: 0.8421 - val_loss: 0.5558 - val_accuracy: 0.8398
# Epoch 9/30
# 35/35 [==============================] - 18s 501ms/step - loss: 0.4510 - accuracy: 0.8493 - val_loss: 0.5502 - val_accuracy: 0.8516
# Epoch 10/30
# 35/35 [==============================] - 18s 506ms/step - loss: 0.3848 - accuracy: 0.8520 - val_loss: 0.4803 - val_accuracy: 0.8359
# Epoch 11/30
# 35/35 [==============================] - 18s 506ms/step - loss: 0.3795 - accuracy: 0.8700 - val_loss: 0.5264 - val_accuracy: 0.8320
# Epoch 12/30
# 35/35 [==============================] - 18s 505ms/step - loss: 0.2956 - accuracy: 0.8890 - val_loss: 0.5822 - val_accuracy: 0.8398
# Epoch 13/30
# 35/35 [==============================] - 18s 503ms/step - loss: 0.2674 - accuracy: 0.8935 - val_loss: 0.7194 - val_accuracy: 0.8008
# Epoch 14/30
# 35/35 [==============================] - 18s 505ms/step - loss: 0.2536 - accuracy: 0.8971 - val_loss: 0.6837 - val_accuracy: 0.8359
# Epoch 15/30
# 35/35 [==============================] - 18s 504ms/step - loss: 0.2451 - accuracy: 0.9088 - val_loss: 0.6877 - val_accuracy: 0.8320
# Epoch 16/30
# 35/35 [==============================] - 18s 514ms/step - loss: 0.2110 - accuracy: 0.9116 - val_loss: 1.0355 - val_accuracy: 0.8125

# %%
model.save("Model.h5")

# %%
accuracy_score = model.evaluate(validation_generator)
print(accuracy_score)
print("Accuracy: {:.4f}%".format(accuracy_score[1] * 100))

print("Loss: ",accuracy_score[0])
# Out:
# 9/9 [==============================] - 6s 711ms/step - loss: 0.4837 - accuracy: 0.8561
# [0.48367244005203247, 0.8561403751373291]
# Accuracy: 85.6140%
# Loss:  0.48367244005203247

# %%
test_path = '/content/drive/MyDrive/val'
test_img_path = test_path+"/01a05ca1-4745-4ee0-966b-fa5d8c34ae9c1527940268826-Campus-Sutra-Printed-Men-V-neck-Blue-T-Shirt-141152794026782-5.jpg"

img = cv2.imread(test_img_path)
resized_img = cv2.resize(img, (331, 331)).reshape(-1, 331, 331, 3)/255

plt.figure(figsize=(6,6))
plt.title("TEST IMAGE")
plt.imshow(resized_img[0])

# %%
predictions = []

for image in sample.filename:
  img = tf.keras.preprocessing.image.load_img(test_path +'/'+ image)
  img = tf.keras.preprocessing.image.img_to_array(img)
  img = tf.keras.preprocessing.image.smart_resize(img, (331, 331))
  img = tf.reshape(img, (-1, 331, 331, 3))
  prediction = model.predict(img/255)
  predictions.append(np.argmax(prediction))

my_submission = pd.DataFrame({'filename': sample.filename, 'neck': predictions})
my_submission = my_submission.astype({"neck": str})
my_submission.to_csv('submission.csv', index=False)

# %%
from sklearn.metrics import accuracy_score

accuracy_=accuracy_score(sample_1.sleeve_length.values,my_submission.sleeve_length.values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-0a2d6cb6ac89> in <module>()
#       1 from sklearn.metrics import accuracy_score
#       2
# ----> 3 accuracy_=accuracy_score(sample_1.sleeve_length.values,my_submission.sleeve_length.values)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sleeve_length'

# %%
accuracy_
